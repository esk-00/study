# %%
import numpy as np

a = np.arange(3)
b = np.arange(-3, 3).reshape((2, 3))
c = np.arange(1, 7).reshape((2, 3))
d = np.arange(6).reshape((3, 2))
e = np.linspace(-1, 1,10)

print("a:", a)
print("b:", b)
print("c:", c)
print("d:", d)
print("e:", e)
# Out:
# a: [0 1 2]
# b: [[-3 -2 -1]
#  [ 0  1  2]]
# c: [[1 2 3]
#  [4 5 6]]
# d: [[0 1]
#  [2 3]
#  [4 5]]
# e: [-1.         -0.77777778 -0.55555556 -0.33333333 -0.11111111  0.11111111
#   0.33333333  0.55555556  0.77777778  1.        ]

# %%
print("a:", a.shape)
print("b:", b.shape)
print("c:", c.shape)
print("d:", d.shape)
print("e:", e.shape)
# Out:
# a: (3,)
# b: (2, 3)
# c: (2, 3)
# d: (3, 2)
# e: (10,)

# %%
li = [[-3, -2, -1],
      [0, 1, 2]]
new = []
for i, j  in enumerate(li):
    print(i, j)
    new.append([])
    for k in j:
        new[i].append(abs(k))
new
# Out:
# 0 [-3, -2, -1]
# 1 [0, 1, 2]
# [[3, 2, 1], [0, 1, 2]]

# %%
np.abs(b)
# Out:
# array([[3, 2, 1],
#        [0, 1, 2]])

# %%
np.sin(e)
# Out:
# array([-0.84147098, -0.70169788, -0.52741539, -0.3271947 , -0.11088263,
#         0.11088263,  0.3271947 ,  0.52741539,  0.70169788,  0.84147098])

# %%
np.cos(e)
# Out:
# array([0.54030231, 0.71247462, 0.84960756, 0.94495695, 0.99383351,
#        0.99383351, 0.94495695, 0.84960756, 0.71247462, 0.54030231])

# %%
np.log(a)
# Out:
# C:\Users\stesk\AppData\Local\Temp\ipykernel_4644\176755284.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(a)
# array([      -inf, 0.        , 0.69314718])

# %%
np.log10(c)
# Out:
# array([[0.        , 0.30103   , 0.47712125],
#        [0.60205999, 0.69897   , 0.77815125]])

# %%
np.exp(a)
# Out:
# array([1.        , 2.71828183, 7.3890561 ])

# %%
a
# Out:
# array([0, 1, 2])

# %%
a + 10
# Out:
# array([10, 11, 12])

# %%
b
# Out:
# array([[-3, -2, -1],
#        [ 0,  1,  2]])

# %%
a + b
# Out:
# array([[-3, -1,  1],
#        [ 0,  2,  4]])

# %%
a1 = a[:, np.newaxis]
a1
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
a + a1
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
c - np.mean(c)
# Out:
# array([[-2.5, -1.5, -0.5],
#        [ 0.5,  1.5,  2.5]])

# %%
b * 2
# Out:
# array([[-6, -4, -2],
#        [ 0,  2,  4]])

# %%
b ** 3
# Out:
# array([[-27,  -8,  -1],
#        [  0,   1,   8]], dtype=int32)

# %%
b - a
# Out:
# array([[-3, -3, -3],
#        [ 0,  0,  0]])

# %%
a * b
# Out:
# array([[ 0, -2, -2],
#        [ 0,  1,  4]])

# %%
a / c
# Out:
# array([[0.        , 0.5       , 0.66666667],
#        [0.        , 0.2       , 0.33333333]])

# %%
c / a
# Out:
# C:\Users\stesk\AppData\Local\Temp\ipykernel_4644\2389470834.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   c / a
# array([[inf, 2. , 1.5],
#        [inf, 5. , 3. ]])

# %%
c / (a+1e-6)
# Out:
# array([[1.00000000e+06, 1.99999800e+00, 1.49999925e+00],
#        [4.00000000e+06, 4.99999500e+00, 2.99999850e+00]])

# %%
np.dot(b, a)
# Out:
# array([-4,  5])

# %%
b @ a
# Out:
# array([-4,  5])

# %%
b @ d
# Out:
# array([[ -8, -14],
#        [ 10,  13]])

# %%
d @ b
# Out:
# array([[  0,   1,   2],
#        [ -6,  -1,   4],
#        [-12,  -3,   6]])

# %%
a  > 1
# Out:
# array([False, False,  True])

# %%
b > 0
# Out:
# array([[False, False, False],
#        [False,  True,  True]])

# %%
np.count_nonzero(b >0)
# Out:
# 2

# %%
np.sum(b > 0)
# Out:
# 2

# %%
np.any(b > 0)
# Out:
# True

# %%
np.all(b > 0)
# Out:
# False

# %%
b[b > 0]
# Out:
# array([1, 2])

# %%
b == c
# Out:
# array([[False, False, False],
#        [False, False, False]])

# %%
a == b
# Out:
# array([[False, False, False],
#        [ True,  True,  True]])

# %%
(b == c) | (a == b)
# Out:
# array([[False, False, False],
#        [ True,  True,  True]])

# %%
b[(b == c) | (a == b)]
# Out:
# array([0, 1, 2])

# %%
np.allclose(b, c)
# Out:
# False

# %%
np.allclose(b, c, atol=10.0)
# Out:
# True

# %%
np.sum(a)
# Out:
# 3

# %%
a.sum()
# Out:
# 3

# %%
np.sum(a > 0)
# Out:
# 2
