# %%
1+1
# Out:
# 2

# %%
# %timeit -n 1000 -r 10 [x*x for x in range(10000)]
# Out:
# 256 μs ± 18.5 μs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)

# %%
# %%timeit -n 1000 -r 10

ret = []
for x in range(10000):
    ret.append(x*x)
# Out:
# 391 μs ± 16.7 μs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)

# %%
pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     3.7.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# asttokens                 3.0.0
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    6.3.0
# certifi                   2025.10.5
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.3.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# flake8                    7.3.0
# idna                      3.11
# ipykernel                 7.1.0
# ipython                   8.37.0
# ipython-genutils          0.2.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# ...

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     3.7.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# asttokens                 3.0.0
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    6.3.0
# certifi                   2025.10.5
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.3.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# flake8                    7.3.0
# idna                      3.11
# ipykernel                 7.1.0
# ipython                   8.37.0
# ipython-genutils          0.2.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# ...
