# %%
import pandas as pd
df_202205 = pd.read_csv("../data/202205health.csv",
                        encoding = "utf-8",
                       index_col = '日付',
                       parse_dates = True)

df_202205
# Out:
#                 歩数  摂取カロリー
# 日付
# 2022-05-01  1439.0  4500.0
# 2022-05-02  8120.0  2420.0
# 2022-05-03     NaN     NaN
# 2022-05-04  2329.0  1500.0
# 2022-05-05     NaN     NaN
# 2022-05-06  3233.0  1800.0
# 2022-05-07  9593.0  2200.0
# 2022-05-08  9213.0  1800.0
# 2022-05-09  5593.0  2500.0

# %%
df_202205_drop = df_202205.dropna()
df_202205_drop
# Out:
#                 歩数  摂取カロリー
# 日付
# 2022-05-01  1439.0  4500.0
# 2022-05-02  8120.0  2420.0
# 2022-05-04  2329.0  1500.0
# 2022-05-06  3233.0  1800.0
# 2022-05-07  9593.0  2200.0
# 2022-05-08  9213.0  1800.0
# 2022-05-09  5593.0  2500.0

# %%
df_202205_fillna = df_202205.fillna(0)
df_202205_fillna
# Out:
#                 歩数  摂取カロリー
# 日付
# 2022-05-01  1439.0  4500.0
# 2022-05-02  8120.0  2420.0
# 2022-05-03     0.0     0.0
# 2022-05-04  2329.0  1500.0
# 2022-05-05     0.0     0.0
# 2022-05-06  3233.0  1800.0
# 2022-05-07  9593.0  2200.0
# 2022-05-08  9213.0  1800.0
# 2022-05-09  5593.0  2500.0

# %%
df_202205_fill = df_202205.fillna(method = 'ffill')
df_202205_fill
# Out:
#                 歩数  摂取カロリー
# 日付
# 2022-05-01  1439.0  4500.0
# 2022-05-02  8120.0  2420.0
# 2022-05-03  8120.0  2420.0
# 2022-05-04  2329.0  1500.0
# 2022-05-05  2329.0  1500.0
# 2022-05-06  3233.0  1800.0
# 2022-05-07  9593.0  2200.0
# 2022-05-08  9213.0  1800.0
# 2022-05-09  5593.0  2500.0

# %%
df_202205_fillmean = df_202205.fillna(df_202205.mean())
df_202205_fillmean
# Out:
#                      歩数       摂取カロリー
# 日付
# 2022-05-01  1439.000000  4500.000000
# 2022-05-02  8120.000000  2420.000000
# 2022-05-03  5645.714286  2388.571429
# 2022-05-04  2329.000000  1500.000000
# 2022-05-05  5645.714286  2388.571429
# 2022-05-06  3233.000000  1800.000000
# 2022-05-07  9593.000000  2200.000000
# 2022-05-08  9213.000000  1800.000000
# 2022-05-09  5593.000000  2500.000000

# %%
import pandas as pd
df = pd.read_pickle("../data/df_202204health.pickle")
df
# Out:
#                歩数  摂取カロリー   歩数/カロリー  運動指数
# date
# 2022-04-01   5439  2500.0  2.175600   LOW
# 2022-04-02   2510  2300.0  1.091304   LOW
# 2022-04-03  10238  1950.0  5.250256   Mid
# 2022-04-04   8209  1850.0  4.437297   Mid
# 2022-04-05   9434  1930.0  4.888083   Mid
# 2022-04-06   7593  1800.0  4.218333   Mid
# 2022-04-07   9320  1940.0  4.804124   Mid
# 2022-04-08   4873  2300.0  2.118696   LOW
# 2022-04-18  2300.0   8475.0  3.684783      0.0     0.0     1.0   Mid
# 2022-04-19  1950.0   8132.0  4.170256      0.0     0.0     1.0   Mid
# 2022-04-20  1800.0  15328.0  8.515556      1.0     0.0     0.0  High
# 2022-04-21  1940.0  12849.0  6.623196      1.0     0.0     0.0  High
# 2022-04-22  2300.0   4029.0  1.751739      0.0     1.0     0.0   LOW
# 2022-04-23  1950.0   3890.0  1.994872      0.0     1.0     0.0   LOW
# 2022-04-24  1850.0   8093.0  4.374595      0.0     0.0     1.0   Mid
# 2022-04-25  1950.0   7823.0  4.011795      0.0     0.0     1.0   Mid
# 2022-04-26  1850.0   7492.0  4.049730      0.0     0.0     1.0   Mid
# 2022-04-27  1930.0   7203.0  3.732124      0.0     0.0     1.0   Mid
# 2022-04-28  1850.0   7302.0  3.947027      0.0     0.0     1.0   Mid
# 2022-04-29  2300.0   6033.0  2.623043      0.0     1.0     0.0   LOW
# 2022-04-30  1950.0   4093.0  2.098974      0.0     1.0     0.0   LOW
# 2022-05-01  4500.0   1439.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-02  2420.0   8120.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-03  2420.0   8120.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-04  1500.0   2329.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-05  1500.0   2329.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-06  1800.0   3233.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-07  2200.0   9593.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-08  1800.0   9213.0       NaN      NaN     NaN     NaN   NaN
# 2022-05-09  2500.0   5593.0       NaN      NaN     NaN     NaN   NaN

# %%
import pandas as pd
df = pd.read_pickle("../data/df_202204health.pickle")
df.head()
# Out:
#                歩数  摂取カロリー   歩数/カロリー 運動指数
# date
# 2022-04-01   5439  2500.0  2.175600  LOW
# 2022-04-02   2510  2300.0  1.091304  LOW
# 2022-04-03  10238  1950.0  5.250256  Mid
# 2022-04-04   8209  1850.0  4.437297  Mid
# 2022-04-05   9434  1930.0  4.888083  Mid

# %%
df.loc[:, "摂取カロリー"].max()
# Out:
# 2500.0

# %%
df.loc[:, "摂取カロリー"].min()
# Out:
# 1800.0

# %%
df.loc[:, "摂取カロリー"].mode()
# Out:
# 0    2300.0
# Name: 摂取カロリー, dtype: float32

# %%
df.loc[:, "摂取カロリー"].mean()
# Out:
# 2026.6666

# %%
df.loc[:, "摂取カロリー"].median()
# Out:
# 1945.0

# %%
df.loc[:, "摂取カロリー"].std()
# Out:
# 205.54944

# %%
df.loc[:, "摂取カロリー"].std(ddof=0)
# Out:
# 202.09459

# %%
df.loc[df.loc[:, "摂取カロリー"] == 2300, :].count()
# Out:
# 歩数         8
# 摂取カロリー     8
# 歩数/カロリー    8
# 運動指数       8
# dtype: int64

# %%
df.describe()
# Out:
#                  歩数       摂取カロリー    歩数/カロリー
# count     30.000000    30.000000  30.000000
# mean    7766.366667  2026.666626   3.929658
# std     2689.269308   205.549438   1.563674
# min     2510.000000  1800.000000   1.091304
# 25%     6661.500000  1870.000000   2.921522
# 50%     7561.000000  1945.000000   4.030762
# 75%     8408.500000  2300.000000   4.421622
# max    15328.000000  2500.000000   8.515556

# %%
df.corr()
# Out:
#                歩数    摂取カロリー   歩数/カロリー
# 歩数       1.000000 -0.498703  0.982828
# 摂取カロリー  -0.498703  1.000000 -0.636438
# 歩数/カロリー  0.982828 -0.636438  1.000000

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
_ = pd.plotting.scatter_matrix(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 _ = pd.plotting.scatter_matrix(df)
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\pandas\plotting\_misc.py:144, in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#      85 """
#      86 Draw a matrix of scatter plots.
#      87
#    (...)
#     141         <AxesSubplot:xlabel='D', ylabel='D'>]], dtype=object)
#     142 """
#     143 plot_backend = _get_plot_backend("matplotlib")
# --> 144 return plot_backend.scatter_matrix(
#     145     frame=frame,
#     146     alpha=alpha,
#     147     figsize=figsize,
#     148     ax=ax,
#     149     grid=grid,
#     150     diagonal=diagonal,
#     151     marker=marker,
#     152     density_kwds=density_kwds,
#     153     hist_kwds=hist_kwds,
#     154     range_padding=range_padding,
#     155     **kwargs,
#     156 )
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\pandas\plotting\_matplotlib\misc.py:50, in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      48 n = df.columns.size
#      49 naxes = n * n
# ---> 50 fig, axes = create_subplots(naxes=naxes, figsize=figsize, ax=ax, squeeze=False)
#      52 # no gaps between subplots
#      53 maybe_adjust_figure(fig, wspace=0, hspace=0)
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\pandas\plotting\_matplotlib\tools.py:223, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     220     subplot_kw = {}
#     222 if ax is None:
# --> 223     fig = plt.figure(**fig_kw)
#     224 else:
#     225     if is_list_like(ax):
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib\pyplot.py:808, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     799 if len(allnums) == max_open_warning >= 1:
#     800     _api.warn_external(
#     801         f"More than {max_open_warning} figures have been opened. "
#     802         f"Figures created through the pyplot interface "
#    (...)
#     805         f"warning, see the rcParam `figure.max_open_warning`).",
#     806         RuntimeWarning)
# --> 808 manager = new_figure_manager(
#     809     num, figsize=figsize, dpi=dpi,
#     810     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     811     FigureClass=FigureClass, **kwargs)
#     812 fig = manager.canvas.figure
#     813 if fig_label:
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib\pyplot.py:326, in new_figure_manager(*args, **kwargs)
#     324 def new_figure_manager(*args, **kwargs):
#     325     """Create a new figure manager instance."""
# --> 326     _warn_if_gui_out_of_main_thread()
#     327     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib\pyplot.py:316, in _warn_if_gui_out_of_main_thread()
#     315 def _warn_if_gui_out_of_main_thread():
# --> 316     if (_get_required_interactive_framework(_get_backend_mod())
#     317             and threading.current_thread() is not threading.main_thread()):
#     318         _api.warn_external(
#     319             "Starting a Matplotlib GUI outside of the main thread will likely "
#     320             "fail.")
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib\pyplot.py:217, in _get_backend_mod()
#     208 """
#     209 Ensure that a backend is selected and return it.
#     210
#     211 This is currently private, but may be made public in the future.
#     212 """
#     213 if _backend_mod is None:
#     214     # Use __getitem__ here to avoid going through the fallback logic (which
#     215     # will (re)import pyplot and then call switch_backend if we need to
#     216     # resolve the auto sentinel)
# --> 217     switch_backend(dict.__getitem__(rcParams, "backend"))
#     218     # Just to be safe.  Interactive mode can be turned on without calling
#     219     # `plt.ion()` so register it again here.  This is safe because multiple
#     220     # calls to `install_repl_displayhook` are no-ops and the registered
#     221     # function respects `mpl.is_interactive()` to determine if it should
#     222     # trigger a draw.
#     223     install_repl_displayhook()
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib\pyplot.py:288, in switch_backend(newbackend)
#     281 # Backends are implemented as modules, but "inherit" default method
#     282 # implementations from backend_bases._Backend.  This is achieved by
#     283 # creating a "class" that inherits from backend_bases._Backend and whose
#     284 # body is filled with the module's globals.
#     286 backend_name = cbook._backend_module_name(newbackend)
# --> 288 class backend_mod(matplotlib.backend_bases._Backend):
#     289     locals().update(vars(importlib.import_module(backend_name)))
#     291 required_framework = _get_required_interactive_framework(backend_mod)
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib\pyplot.py:289, in switch_backend.<locals>.backend_mod()
#     288 class backend_mod(matplotlib.backend_bases._Backend):
# --> 289     locals().update(vars(importlib.import_module(backend_name)))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       3 __version__ = "0.2.1"
#       5 # we can't ''.join(...) otherwise finding the version number at build time requires
#       6 # import which introduces IPython and matplotlib at build time, and thus circular
#       7 # dependencies.
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib_inline\backend_inline.py:236
#     231                 ip.events.unregister("post_run_cell", configure_once)
#     233             ip.events.register("post_run_cell", configure_once)
# --> 236 _enable_matplotlib_integration()
#     239 def _fetch_figure_metadata(fig):
#     240     """Get some metadata to help with displaying a figure."""
#
# File ~\OneDrive\デスクトップ\study\data_engineer\venv\lib\site-packages\matplotlib_inline\backend_inline.py:218, in _enable_matplotlib_integration()
#     216     backend = matplotlib.get_backend(auto_select=False)
#     217 else:
# --> 218     backend = matplotlib.rcParams._get("backend")
#     220 if ip and backend in ("inline", "module://matplotlib_inline.backend_inline"):
#     221     from IPython.core.pylabtools import activate_matplotlib
#
# AttributeError: 'RcParams' object has no attribute '_get'

# %%
df.loc[:, ["歩数", "摂取カロリー"]]
# Out:
#                歩数  摂取カロリー
# date
# 2022-04-01   5439  2500.0
# 2022-04-02   2510  2300.0
# 2022-04-03  10238  1950.0
# 2022-04-04   8209  1850.0
# 2022-04-05   9434  1930.0
# 2022-04-06   7593  1800.0
# 2022-04-07   9320  1940.0
# 2022-04-08   4873  2300.0
# 2022-04-09  12045  1950.0
# 2022-04-10   7493  1850.0
# 2022-04-11   7289  1930.0
# 2022-04-12   6481  2300.0
# 2022-04-13  10287  1800.0
# 2022-04-14   8043  1940.0
# 2022-04-15   7435  2300.0
# 2022-04-16   7529  2300.0
# 2022-04-17   8031  1940.0
# 2022-04-18   8475  2300.0
# 2022-04-19   8132  1950.0
# 2022-04-20  15328  1800.0
# 2022-04-21  12849  1940.0
# 2022-04-22   4029  2300.0
# 2022-04-23   3890  1950.0
# 2022-04-24   8093  1850.0
# 2022-04-25   7823  1950.0
# 2022-04-26   7492  1850.0
# 2022-04-27   7203  1930.0
# 2022-04-28   7302  1850.0
# 2022-04-29   6033  2300.0
# 2022-04-30   4093  1950.0

# %%
df.loc[:, ["歩数", "摂取カロリー"]].values
# Out:
# array([[ 5439.,  2500.],
#        [ 2510.,  2300.],
#        [10238.,  1950.],
#        [ 8209.,  1850.],
#        [ 9434.,  1930.],
#        [ 7593.,  1800.],
#        [ 9320.,  1940.],
#        [ 4873.,  2300.],
#        [12045.,  1950.],
#        [ 7493.,  1850.],
#        [ 7289.,  1930.],
#        [ 6481.,  2300.],
#        [10287.,  1800.],
#        [ 8043.,  1940.],
#        [ 7435.,  2300.],
#        [ 7529.,  2300.],
#        [ 8031.,  1940.],
#        [ 8475.,  2300.],
#        [ 8132.,  1950.],
#        [15328.,  1800.],
#        [12849.,  1940.],
#        [ 4029.,  2300.],
#        [ 3890.,  1950.],
#        [ 8093.,  1850.],
#        [ 7823.,  1950.],
#        [ 7492.,  1850.],
#        [ 7203.,  1930.],
#        [ 7302.,  1850.],
#        [ 6033.,  2300.],
#        [ 4093.,  1950.]])
